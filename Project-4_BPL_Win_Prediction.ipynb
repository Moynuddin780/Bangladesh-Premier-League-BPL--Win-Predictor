# %%
import numpy as np 
import pandas as pd

# %%
match = pd.read_csv(r"C:\Users\Moynuddin\OneDrive\Desktop\Jupyter Projects\bpl_synthetic_dataset_corrected.csv")
delivery = pd.read_csv(r"C:\Users\Moynuddin\OneDrive\Desktop\Jupyter Projects\bpl_deliveries_synthetic.csv")

# %%
match.shape
# Out:
# (640, 17)

# %%
delivery.head()
# Out:
#    match_id  inning   batting_team    bowling_team  over  ball        batsman  \
# 0         1       1  Khulna Tigers  Rangpur Riders     1     1   Anamul Haque
# 1         1       1  Khulna Tigers  Rangpur Riders     1     2   Anamul Haque
# 2         1       1  Khulna Tigers  Rangpur Riders     1     3  Andre Russell
# 3         1       1  Khulna Tigers  Rangpur Riders     1     4      Yasir Ali
# 4         1       1  Khulna Tigers  Rangpur Riders     1     5      Yasir Ali
#
#      non_striker         bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0  Andre Russell      Jason Roy              0  ...         0            0
# 1  Shahid Afridi  Mohammad Nabi              0  ...         0            1
# 2  Andre Russell  Mohammad Nabi              0  ...         1            0
# 3  Andre Russell   Benny Howell              0  ...         0            0
# 4  Shahid Afridi  Mohammad Nabi              0  ...         1            0
#
# ...

# %%
total_score_df = delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         452
# 1            1       2         439
# 2            2       1         430
# 3            2       2         448
# 4            3       1         467
# ...        ...     ...         ...
# 1435       718       2         447
# 1436       719       1         506
# 1437       719       2         465
# 1438       720       1         462
# 1439       720       2         460
#
# [1440 rows x 3 columns]

# %%
total_score_df = total_score_df[total_score_df['inning']==1]

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df['team1'].unique()
# Out:
# array(['Khulna Tigers', 'Rangpur Riders', 'Barishal Bulls',
#        'Sylhet Strikers', 'Rajshahi Kings', 'Dhaka Dominators',
#        'Comilla Victorians', 'Chattogram Challengers'], dtype=object)

# %%
teams =[
    'Khulna Tigers', 
    'Rangpur Riders', 
    'Barishal Bulls',
    'Sylhet Strikers', 
    'Rajshahi Kings', 
    'Dhaka Dominators',
    'Comilla Victorians', 
    'Chattogram Challengers']

# %%
delivery_df['city'].unique()

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (640, 19)

# %%
match_df['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    640
# Name: count, dtype: int64

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
delivery_df = match_df.merge(delivery,on='match_id')

# %%
delivery_df = delivery_df[delivery_df['inning']==2]

# %%
delivery_df.shape
# Out:
# (76800, 24)

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
#delivery_df

# %%
delivery_df['balls_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id        city                  winner  total_runs_x  inning  \
# 120            1  Chattogram           Khulna Tigers           452       2
# 121            1  Chattogram           Khulna Tigers           452       2
# 122            1  Chattogram           Khulna Tigers           452       2
# 123            1  Chattogram           Khulna Tigers           452       2
# 124            1  Chattogram           Khulna Tigers           452       2
# ...          ...         ...                     ...           ...     ...
# 153595       640      Khulna  Chattogram Challengers           512       2
# 153596       640      Khulna  Chattogram Challengers           512       2
# 153597       640      Khulna  Chattogram Challengers           512       2
# 153598       640      Khulna  Chattogram Challengers           512       2
# 153599       640      Khulna  Chattogram Challengers           512       2
#
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('match_id')['player_dismissed'].cumsum().values
delivery_df['wickets'] = 10 - wickets
delivery_df.head(20)
# Out:
#      match_id        city         winner  total_runs_x  inning   batting_team  \
# 120         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 121         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 122         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 123         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 124         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 125         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 126         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 127         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 128         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 129         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# 130         1  Chattogram  Khulna Tigers           452       2  Khulna Tigers
# ...

# %%
delivery_df.tail()
# Out:
#         match_id    city                  winner  total_runs_x  inning  \
# 153595       640  Khulna  Chattogram Challengers           512       2
# 153596       640  Khulna  Chattogram Challengers           512       2
# 153597       640  Khulna  Chattogram Challengers           512       2
# 153598       640  Khulna  Chattogram Challengers           512       2
# 153599       640  Khulna  Chattogram Challengers           512       2
#
#          batting_team    bowling_team  over  ball        batsman  ...  \
# 153595  Khulna Tigers  Rajshahi Kings    20     2  Shahid Afridi  ...
# 153596  Khulna Tigers  Rajshahi Kings    20     3      Yasir Ali  ...
# 153597  Khulna Tigers  Rajshahi Kings    20     4   Anamul Haque  ...
# 153598  Khulna Tigers  Rajshahi Kings    20     5      Yasir Ali  ...
# 153599  Khulna Tigers  Rajshahi Kings    20     6  Andre Russell  ...
#
#        batsman_runs extra_runs  total_runs_y  player_dismissed  \
# ...

# %%
#crr(current run rate) = curren runs/ overs(balls)

delivery_df['crr'] = (delivery_df['current_score']*6) / (120 - delivery_df['balls_left'])

# %%
#rrr(required run rate) = runs left / balls left 

delivery_df['rrr'] = (delivery_df['runs_left']*6) / ( delivery_df['balls_left'])

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
final_df =  delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#          batting_team     bowling_team        city  runs_left  balls_left  \
# 111776  Khulna Tigers  Sylhet Strikers  Chattogram        219          63
#
#         wickets  total_runs_x        crr        rrr  result
# 111776      -47           443  23.578947  20.857143       0

# %%
final_df.dropna(inplace=True)
final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
final_df = final_df[final_df['balls_left']!=0]

# %%
x = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
#                   batting_team        bowling_team        city  runs_left  \
# 137884      Comilla Victorians    Dhaka Dominators  Chattogram        431
# 83007         Dhaka Dominators       Khulna Tigers    Barishal        117
# 111811           Khulna Tigers     Sylhet Strikers  Chattogram         90
# 130526          Rajshahi Kings     Sylhet Strikers    Barishal        203
# 110290      Comilla Victorians     Sylhet Strikers      Khulna        434
# ...                        ...                 ...         ...        ...
# 41173            Khulna Tigers      Rangpur Riders  Chattogram        381
# 122121          Barishal Bulls      Rajshahi Kings      Khulna        170
# 152534         Sylhet Strikers      Rangpur Riders  Chattogram        377
# 79112       Comilla Victorians       Khulna Tigers  Chattogram        333
# 62044   Chattogram Challengers  Comilla Victorians    Barishal        417
#
#         balls_left  wickets  total_runs_x        crr        rrr
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder


trf = ColumnTransformer([('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])],remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %%
pipe = Pipeline(steps=[
    ('step1',trf), 
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\Users\Moynuddin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:1651: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
# ...

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8620667016806722

# %%
pipe.predict_proba(x_test)[8]
# Out:
# array([0.85787842, 0.14212158])

# %%
import numpy as np

def match_progression(x_df, match_id, pipe): 
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left', 'wickets', 'total_runs_x', 'crr', 'rrr']]
    temp_df = temp_df[temp_df['balls_left'] != 0]

    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0] * 100, 1)
    temp_df['win'] = np.round(result.T[1] * 100, 1)
    temp_df['end_of_over'] = range(1, temp_df.shape[0] + 1)

    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0, target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)

    # ✅ Extract wickets from DataFrame and ensure it's a list
    wickets = list(temp_df['wickets'].values)

    # ✅ Now modify wickets
    new_wickets = wickets[:]  # Copy the original list
    new_wickets.insert(0, 10)  # Insert 10 at the start

    wickets.append(0)  # Append 0 at the end of the original list
    wickets = np.array(wickets)  # Convert to NumPy array
    nw = np.array(new_wickets)   # Convert new_wickets to NumPy array

    temp_df['wickets_in_over'] = (nw - wickets)[:temp_df.shape[0]]

    print("Target-", target)
    temp_df = temp_df[['end_of_over', 'runs_after_over', 'wickets_in_over', 'lose', 'win']]
    
    return temp_df, target

# %%
# Calling the function
temp_df, target = match_progression(delivery_df, 1, pipe)
# Out:
# Target- 452

# %%
temp_df
# Out:
#      end_of_over  runs_after_over  wickets_in_over  lose   win
# 125            1               20                6  85.4  14.6
# 131            2               28                6  84.9  15.1
# 137            3               17                6  85.2  14.8
# 143            4               19                6  85.2  14.8
# 149            5               35                6  84.9  15.1
# 155            6               19                6  85.0  15.0
# 161            7               27                6  84.9  15.1
# 167            8               26                6  84.9  15.1
# 173            9               17                6  85.0  15.0
# 179           10               22                6  85.0  15.0
# 185           11               19                6  85.0  15.0
# 191           12               25                6  85.0  15.0
# 197           13               22                6  85.0  15.0
# 203           14               21                6  85.0  15.0
# ...

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(20,10))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-452')

# %%
delivery_df['city'].unique()
# Out:
# array(['Chattogram', 'Khulna', 'Barishal', 'Rangpur', 'Dhaka', 'Sylhet'],
#       dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
teams
# Out:
# ['Khulna Tigers',
#  'Rangpur Riders',
#  'Barishal Bulls',
#  'Sylhet Strikers',
#  'Rajshahi Kings',
#  'Dhaka Dominators',
#  'Comilla Victorians',
#  'Chattogram Challengers']
